# %% [markdown]
# <a href="https://colab.research.google.com/github/Akhila2403A51L40/B52Data_Mining/blob/main/Lab06ADM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
data = {'Category': ['A', 'B', 'C', 'A', 'B']}

# %%
print(data)
# Out:
# {'Category': ['A', 'B', 'C', 'A', 'B']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Category
# 0        A
# 1        B
# 2        C
# 3        A
# 4        B

# %%
label_encoder = LabelEncoder()

# %%
df['Label_Encoded'] = label_encoder.fit_transform(df['Category'])

# %%
one_hot_encoded = pd.get_dummies(df['Category'], prefix='Category')

# %%
df = pd.concat([df, one_hot_encoded], axis=1)

# %%
print(df)
# Out:
#   Category  Label_Encoded  Category_A  Category_B  Category_C
# 0        A              0        True       False       False
# 1        B              1       False        True       False
# 2        C              2       False       False        True
# 3        A              0        True       False       False
# 4        B              1       False        True       False

# %%
from datetime import datetime

# %%
data = {'Name': ['Alice', 'Bob'], 'Date_of_Birth': ['1990-05-14', '1985-08-23']}

# %%
type(data)
# Out:
# dict

# %%
print(data)
# Out:
# {'Name': ['Alice', 'Bob'], 'Date_of_Birth': ['1990-05-14', '1985-08-23']}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Name Date_of_Birth
# 0  Alice    1990-05-14
# 1    Bob    1985-08-23

# %%
df['Date_of_Birth'] = pd.to_datetime(df['Date_of_Birth'])

# %%
current_year = datetime.now().year

# %%
df['Age'] = current_year - df['Date_of_Birth'].dt.year

# %%
print(df)
# Out:
#     Name Date_of_Birth  Age
# 0  Alice    1990-05-14   35
# 1    Bob    1985-08-23   40

# %%
data = {'Category': ['A', 'A', 'B', 'B', 'C'],'Value': [10, 20, 10, 30, 40]}

# %%
print(data)
# Out:
# {'Category': ['A', 'A', 'B', 'B', 'C'], 'Value': [10, 20, 10, 30, 40]}

# %%
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#   Category  Value
# 0        A     10
# 1        A     20
# 2        B     10
# 3        B     30
# 4        C     40

# %%
grouped = df.groupby('Category').agg({'Value': ['sum', 'mean']})

# %%
print("Grouped Data:\n", grouped)
# Out:
# Grouped Data:
#           Value
#            sum  mean
# Category
# A           30  15.0
# B           40  20.0
# C           40  40.0

# %%
pivot = df.pivot_table(index='Category', values='Value', aggfunc=['sum','mean'])

# %%
print("\nPivot Table:\n", pivot)
# Out:
# Pivot Table:
#             sum  mean
#          Value Value
# Category
# A           30  15.0
# B           40  20.0
# C           40  40.0
